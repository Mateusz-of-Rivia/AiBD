# %% [markdown]
# Sprawozdanie 2
#
# Łączenie z bazą danych i instrukcja select

# %%
from sqlalchemy import create_engine
import pandas as pd

#Łączenie się z bazą danych
db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"

db = create_engine(db_string)

connection_sqlalchemy = db.connect()

# %% [markdown]
# Zadanie 1
#
# Ile kategorii filmów mamy w wypożyczalni?

# %%
df = pd.read_sql('select count(name) from category', con=connection_sqlalchemy)
df
# Out:
#    count
# 0     16

# %% [markdown]
# Odpowiedź: W wypożyczalni jest 16 kategorii filmów.

# %% [markdown]
# Zadanie 2
#
# Wyświetl listę kategorii w kolejności alfabetycznej.

# %%
df = pd.read_sql('select * from category order by name', con=connection_sqlalchemy)
df
# Out:
#     category_id         name         last_update
# 0             1       Action 2006-02-15 09:46:27
# 1             2    Animation 2006-02-15 09:46:27
# 2             3     Children 2006-02-15 09:46:27
# 3             4     Classics 2006-02-15 09:46:27
# 4             5       Comedy 2006-02-15 09:46:27
# 5             6  Documentary 2006-02-15 09:46:27
# 6             7        Drama 2006-02-15 09:46:27
# 7             8       Family 2006-02-15 09:46:27
# 8             9      Foreign 2006-02-15 09:46:27
# 9            10        Games 2006-02-15 09:46:27
# 10           11       Horror 2006-02-15 09:46:27
# 11           12        Music 2006-02-15 09:46:27
# 12           13          New 2006-02-15 09:46:27
# 13           14       Sci-Fi 2006-02-15 09:46:27
# 14           15       Sports 2006-02-15 09:46:27
# 15           16       Travel 2006-02-15 09:46:27

# %% [markdown]
# Zadanie 3
#
# Znajdź najstarszy i najmłodszy film do wypożyczenia.

# %%
df = pd.read_sql('select * from film order by release_year', con=connection_sqlalchemy)
df
# Out:
#      film_id              title  \
# 0        133    Chamber Italian
# 1        384   Grosse Wonderful
# 2          8    Airport Pollock
# 3         98  Bright Encounters
# 4          1   Academy Dinosaur
# ..       ...                ...
# 995      996     Young Language
# 996      997         Youth Kick
# 997      998       Zhivago Core
# 998      999  Zoolander Fiction
# 999     1000          Zorro Ark
#
#                                            description  release_year  \
# 0    A Fateful Reflection of a Moose And a Husband ...          2006
# 1    A Epic Drama of a Cat And a Explorer who must ...          2006
# 2    A Epic Tale of a Moose And a Girl who must Con...          2006
# 3    A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4    A Epic Drama of a Feminist And a Mad Scientist...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %% [markdown]
# Odpowiedź: Wszystkie filmy są z roku 2006.

# %% [markdown]
# Zadanie 4
#
# Ile wypożyczeń odbyło się między 2005-07-01 a 2005-08-01?

# %%
df = pd.read_sql("select count(rental_date) from rental where rental_date BETWEEN '2005-07-01 00:00:00'::timestamp AND '2005-08-01 00:00:00'::timestamp",con=connection_sqlalchemy)
df
# Out:
#    count
# 0   6709

# %% [markdown]
# Zadanie 5
#
#
# Ile wypożyczeń odbyło się między 2010-01-01 a 2011-02-01?

# %%
df = pd.read_sql("select count(rental_date) from rental where rental_date BETWEEN '2010-01-01 00:00:00'::timestamp AND '2011-02-01 00:00:00'::timestamp",con=connection_sqlalchemy)
df
# Out:
#    count
# 0      0

# %% [markdown]
# Zadanie 6
#
# Znajdź największą płatność wypożyczenia.

# %%
df = pd.read_sql("select amount from payment order by amount",con=connection_sqlalchemy)
df
# Out:
#        amount
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
# ...       ...
# 14591   11.99
# 14592   11.99
# 14593   11.99
# 14594   11.99
# 14595   11.99
#
# [14596 rows x 1 columns]

# %% [markdown]
# Odpowiedź: Największa płatność wypoyczenia wynosi 11.99 zł.

# %% [markdown]
# Zadanie 7
#
# Znajdź wszystkich klientów z Polski, Nigerii lub Bangladeszu.

# %%
df = pd.read_sql_query("select * from customer_list where country = 'Poland' or country = 'Nigeria' or country = 'Bangladesh'",con=connection_sqlalchemy)
df
# Out:
#      id              name                         address zip code  \
# 0   284     Sonia Gregory              1279 Udine Parkway    75860
# 1   318       Brian Wyman                 1769 Iwaki Lane    25787
# 2   572   Sidney Burleson             1405 Hagonoy Avenue    86587
# 3   409    Rodney Moeller          1936 Lapu-Lapu Parkway     7122
# 4   332    Stephen Qualls                1838 Tabriz Lane     1195
# 5   286       Velma Lucas            1155 Liaocheng Place    22650
# 6    80      Marilyn Ross                1888 Kabul Drive    20936
# 7   198      Elsie Kelley                 955 Bamenda Way     1545
# 8   103   Gladys Hamilton                 1177 Jelets Way     3305
# 9   329    Frank Waggoner             1816 Bydgoszcz Loop    64308
# 10  128   Marjorie Tucker        1050 Garden Grove Avenue     4999
# 11   18      Carol Garcia                320 Brest Avenue    43331
# 12  270       Leah Curtis                  906 Goinia Way    83565
# ...

# %% [markdown]
# Zadanie 8
#
# Gdzie mieszkają członkowie personelu?

# %%
df = pd.read_sql_query("select address, city, country from staff_list ",con=connection_sqlalchemy)
df
# Out:
#                 address        city    country
# 0     23 Workhaven Lane  Lethbridge     Canada
# 1  1411 Lillydale Drive   Woodridge  Australia

# %% [markdown]
# Zadanie 9
#
# Ilu pracowników mieszka w Argentynie lub Hiszpanii?

# %%
df = pd.read_sql_query("select count(country) from staff_list where country = 'Argentine' or country = 'Spain'",con=connection_sqlalchemy)
df
# Out:
#    count
# 0      0

# %% [markdown]
# Zadanie 10
#
# Jakie kategorie filmów zostały wypożyczone przez klientów?

# %%
df = pd.read_sql('select category from sales_by_film_category where total_sales > 0', con=connection_sqlalchemy)
df
# Out:
#        category
# 0        Sports
# 1        Sci-Fi
# 2     Animation
# 3         Drama
# 4        Comedy
# 5           New
# 6        Action
# 7       Foreign
# 8         Games
# 9        Family
# 10  Documentary
# 11       Horror
# 12     Classics
# 13     Children
# 14       Travel
# 15        Music

# %% [markdown]
# Zadanie 11
#
# Znajdź wszystkie kategorie filmów wypożyczonych w Ameryce.

# %%
df = pd.read_sql("select distinct category from film_list where fid in (select film_id from inventory where inventory_id in (select inventory_id from rental where customer_id in (select id from customer_list where country = 'United States')))", con=connection_sqlalchemy)
df
# Out:
#        category
# 0        Sports
# 1      Classics
# 2           New
# 3        Family
# 4        Comedy
# 5     Animation
# 6        Travel
# 7         Music
# 8         Drama
# 9        Horror
# 10       Sci-Fi
# 11        Games
# 12  Documentary
# 13      Foreign
# 14       Action
# 15     Children

# %% [markdown]
# Zadanie 12
#
# Znajdź wszystkie tytuły filmów, w których grał: Olympia Pfeiffer lub Julia Zellweger lub Ellen Presley

# %%
df = pd.read_sql("select title from film where film_id in(select film_id from film_actor where actor_id in (select actor_id from actor where (first_name like 'Olympia' and last_name like 'Pfeiffer') or (first_name like 'Julia' and last_name like 'Zellweger') or (first_name like 'Ellen' and last_name like 'Presley')))", con=connection_sqlalchemy)
df
# Out:
#                 title
# 0      Express Lonely
# 1     Bilko Anonymous
# 2    Effect Gladiator
# 3   Contact Anonymous
# 4         Others Soup
# ..                ...
# 64      Hanky October
# 65    Tourist Pelican
# 66   Detective Vision
# 67       None Spiking
# 68     Homeward Cider
#
# [69 rows x 1 columns]
